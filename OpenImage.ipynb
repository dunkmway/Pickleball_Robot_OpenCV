# %%
import cv2 as cv
import numpy as np
import time
from IPython.display import Image

directory = './'
filename = 'PB Calibration - Matthew.jpg'

image = cv.imread(directory + filename, cv.IMREAD_COLOR)[:, :, ::-1]
Image(directory + filename)
