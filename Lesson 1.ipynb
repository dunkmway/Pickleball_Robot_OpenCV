# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
# display image in the notebook
Image(filename='Images/Darth-Vader.jpeg')

# %%
filePath = 'Images/Darth-Vader.jpeg'
img = cv2.imread(filePath, 1)
reversed_image = img[:, :, ::-1]
cv2.imwrite('test.jpg', reversed_image)
# plt.imshow(img)
Image('test.jpg')
