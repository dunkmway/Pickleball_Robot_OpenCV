# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image
# Out:
# done

# %%
# display image in the notebook
Image(filename='Images/Darth-Vader.jpeg')

# %%
img = cv2.imread('Images/Darth-Vader.jpeg', 1)
reversed_image = img[:, :, ::-1]
# plt.imshow(img)
plt.imshow(reversed_image)
